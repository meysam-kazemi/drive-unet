# %%
# Libraries

import os
import time
import random
import numpy as np
import cv2
import torch
from torch.utils.data import Dataset
import torch.nn as nn
import torch.nn.functional as F
from glob import glob
from torch.utils.data import DataLoader
from torch.cuda.amp import GradScaler, autocast
import cv2
import time
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
def fig(img):
    plt.imshow(img, "gray", vmin=0, vmax=255);plt.axis(False)

# %%
train_x = sorted(glob("./data/dataset/train/origin/*"))
train_x2 = sorted(glob("./data/Drive/training/images/*"))
train_x2
# Out:
# ['./data/Drive/training/images/21_training.tif',
#  './data/Drive/training/images/22_training.tif',
#  './data/Drive/training/images/23_training.tif',
#  './data/Drive/training/images/24_training.tif',
#  './data/Drive/training/images/25_training.tif',
#  './data/Drive/training/images/26_training.tif',
#  './data/Drive/training/images/27_training.tif',
#  './data/Drive/training/images/28_training.tif',
#  './data/Drive/training/images/29_training.tif',
#  './data/Drive/training/images/30_training.tif',
#  './data/Drive/training/images/31_training.tif',
#  './data/Drive/training/images/32_training.tif',
#  './data/Drive/training/images/33_training.tif',
#  './data/Drive/training/images/34_training.tif',
#  './data/Drive/training/images/35_training.tif',
#  './data/Drive/training/images/36_training.tif',
#  './data/Drive/training/images/37_training.tif',
#  './data/Drive/training/images/38_training.tif',
#  './data/Drive/training/images/39_training.tif',
#  './data/Drive/training/images/40_training.tif']

# %%
a = cv2.imread(train_x[0], 0)
b = cv2.imread(train_x2[0], 0)
np.all(a==b)
# Out:
# True

# %%
fig(a)

# %%
fig(b)

# %%
fig(b-a)
